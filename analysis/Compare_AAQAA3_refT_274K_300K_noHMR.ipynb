# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import pyblock
from scipy.special import logsumexp
from scipy.special import softmax

# matplotlib settings
# --- Publication style settings ---
plt.rcParams.update({
    # Font
    "font.family": "Times New Roman",
    "font.serif": ["Arial"],  # or other preferred serif font
    "mathtext.fontset": "cm",            # Computer Modern for math text
    "text.usetex": False,                 # Use LaTeX for text rendering]
    "pdf.fonttype": 42,                 # Use LaTeX for text rendering

    # Figure
    "figure.figsize": (6, 4),            # width, height in inches
    "figure.dpi": 300,                   # high resolution

    # Axes
    "axes.titlesize": 14,
    "axes.labelsize": 12,
    "axes.linewidth": 1.2,
    "axes.grid": True,                   # optional, remove if you want no grid
    "grid.linestyle": "--",
    "grid.alpha": 0.7,

    # Ticks
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": True,
    "ytick.right": True,

    # Lines
    "lines.linewidth": 2,
    "lines.markersize": 6,

    # Legend
    "legend.fontsize": 10,
    "legend.frameon": False
})


output_path = './plots_AAQAA3_274K_vs_300K/'
prod_name = '274K_vs_300K'
path = '../OPES_multiT/AAQAA3/PRODUCTION_OPES_multiT_2fs_noHMR/alldata/'

# %%
# Rg as a function of temp (avg + std_err) - error obtained by blocking analysis on concatenated dataset


# load data
df274 = pd.read_csv('plots_AAQAA3_274K/274K_noHMR_Rg_vs_Temp.csv')
df300 = pd.read_csv('plots_AAQAA3_300K/300K_noHMR_Rg_vs_Temp.csv')

plt.figure(figsize = (4,3))
plt.errorbar(df274['T (K)'], df274['Rg (nm)'], df274['±'], fmt='o-', color = "#779AEC", capsize = 2, markersize = 5, linewidth=0.7, elinewidth=0.7, label = '274 K ref-T')
plt.errorbar(df300['T (K)'], df300['Rg (nm)'], df300['±'], fmt='o-', color = 'purple', capsize = 2, markersize = 5, linewidth=0.7, elinewidth=0.7, label = '300 K ref-T')
plt.xlabel('Temperature (K)')
plt.ylabel('R$_g$ (nm)')
plt.ylim(0.9,1.1)
plt.legend()
plt.tight_layout()
plt.savefig(output_path+f"{prod_name}_Rg_vs_Temp.pdf")
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
# Rg distribution at 300 K (avg ± std_err)



# load data
df274= pd.read_csv('plots_AAQAA3_274K/274K_noHMR_prob_Rg_300K.csv')
df300= pd.read_csv('plots_AAQAA3_300K/300K_noHMR_prob_Rg_300K.csv')


# plot PMF with blocking error bars
plt.figure(figsize = (4,3))
plt.title(f"300 K")
plt.errorbar(df274['Rg (nm)'], df274['p(Rg)'], yerr=df274['±'], fmt='o-', markersize=5, capsize=2, linewidth=1., elinewidth=1., color='#779AEC', label = '274 K ref-T')
plt.errorbar(df300['Rg (nm)'], df300['p(Rg)'], yerr=df300['±'], fmt='o-', markersize=5, capsize=2, linewidth=1., elinewidth=1., color='purple', label = '300 K ref-T')
plt.xlabel("R$_g$ (nm)")
plt.ylabel("p(R$_g$)")

# load and plot the average rg
avg1 = pd.read_csv('plots_AAQAA3_300K/300K_noHMR_Rg_at_300K.csv')
avg2 = pd.read_csv('plots_AAQAA3_274K/274K_noHMR_Rg_at_300K.csv')

plt.axvline(avg1['Rg (nm)'][0], color = 'purple', linewidth=1.5)
plt.axvspan(avg1['Rg (nm)'][0]-avg1['±'][0],avg1['Rg (nm)'][0]+avg1['±'][0], color = 'purple', alpha=0.3)
plt.axvline(avg2['Rg (nm)'][0], color = '#779AEC', linewidth=1.5)
plt.axvspan(avg2['Rg (nm)'][0]-avg2['±'][0],avg2['Rg (nm)'][0]+avg2['±'][0], color = '#779AEC', alpha=0.3)

plt.legend()
plt.tight_layout()
plt.savefig(output_path+f"{prod_name}_prob_Rg_300K.pdf")
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
# Helical fraction as a function of temperature from DSSP (H, G, I)

# load data
df274 = pd.read_csv('plots_AAQAA3_274K/274K_noHMR_HelicalFrac_vs_Temp.csv')
df300 = pd.read_csv('plots_AAQAA3_300K/300K_noHMR_HelicalFrac_vs_Temp.csv')

plt.figure(figsize = (4,3))
plt.errorbar(df274['T (K)'], df274['Helix (%)'], df274['±'], fmt='o-', color = '#779AEC', capsize = 2, markersize = 5, linewidth=0.7, elinewidth=0.7, label = '274 K ref-T')
plt.errorbar(df300['T (K)'], df300['Helix (%)'], df300['±'], fmt='o-', color = 'purple', capsize = 2, markersize = 5, linewidth=0.7, elinewidth=0.7, label = '300 K ref-T')
plt.xlabel('Temperature (K)')
plt.ylabel('Fraction helix')
plt.ylim(0, 0.5)
plt.legend()
plt.tight_layout()
plt.savefig(output_path+f"{prod_name}_HelicalFrac_vs_Temp.pdf")

# %%
# Helicity at 300 K

# save data
df274= pd.read_csv('plots_AAQAA3_274K/274K_noHMR_perres_helicity_300K.csv')
df300= pd.read_csv('plots_AAQAA3_300K/300K_noHMR_perres_helicity_300K.csv')

# plot PMF with blocking error bars
plt.figure(figsize = (4,3))
plt.title(f"300 K")
plt.errorbar(df274['Residue'], df274['Fraction helix'], yerr=df274['±'], fmt='o-', markersize=5, capsize=2, linewidth=1., elinewidth=1., color='#779AEC', label = '274 K ref-T')
plt.errorbar(df300['Residue'], df300['Fraction helix'], yerr=df300['±'], fmt='o-', markersize=5, capsize=2, linewidth=1., elinewidth=1., color='purple', label = '300 K ref-T')
plt.xlabel("Residue")
plt.ylabel("Fraction helix")
plt.ylim(0,0.5)
plt.legend()
plt.tight_layout()
plt.savefig(output_path+f"{prod_name}_perres_helicity_300K.pdf")

# %%
# Helical fraction as a function of temperature from DSSP (H, G, I)

# load data
df274 = pd.read_csv('plots_AAQAA3_274K/274K_noHMR_PPIIFrac_vs_Temp.csv')
df300 = pd.read_csv('plots_AAQAA3_300K/300K_noHMR_PPIIFrac_vs_Temp.csv')

plt.figure(figsize = (4,3))
plt.errorbar(df274['T (K)'], df274['Helix (%)'], df274['±'], fmt='o-', color = '#779AEC', capsize = 2, markersize = 5, linewidth=0.7, elinewidth=0.7, label = '274 K ref-T')
plt.errorbar(df300['T (K)'], df300['Helix (%)'], df300['±'], fmt='o-', color = 'purple', capsize = 2, markersize = 5, linewidth=0.7, elinewidth=0.7, label = '300 K ref-T')
plt.xlabel('Temperature (K)')
plt.ylabel('Fraction PPII')
plt.ylim(0, 0.5)
plt.legend()
plt.tight_layout()
plt.savefig(output_path+f"{prod_name}_PPIIFrac_vs_Temp.pdf")

# %%
# PPII at 300 K

# save data
df274= pd.read_csv('plots_AAQAA3_274K/274K_noHMR_perres_PPII_300K.csv')
df300= pd.read_csv('plots_AAQAA3_300K/300K_noHMR_perres_PPII_300K.csv')

# plot PMF with blocking error bars
plt.figure(figsize = (4,3))
plt.title(f"300 K")
plt.errorbar(df274['Residue'], df274['Fraction helix'], yerr=df274['±'], fmt='o-', markersize=5, capsize=2, linewidth=1., elinewidth=1., color='#779AEC', label = '274 K ref-T')
plt.errorbar(df300['Residue'], df300['Fraction helix'], yerr=df300['±'], fmt='o-', markersize=5, capsize=2, linewidth=1., elinewidth=1., color='purple', label = '300 K ref-T')
plt.xlabel("Residue")
plt.ylabel("Fraction PPII")
plt.ylim(0,0.5)
plt.legend()
plt.tight_layout()
plt.savefig(output_path+f"{prod_name}_perres_PPII_300K.pdf")
